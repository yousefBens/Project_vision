# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Nov 15 21:32:56 2018

@author: Noel
"""

import numpy as np
import cv2
from matplotlib import pyplot as plt

## Chemin pour trouver les images
repertory = '../images/Acquisitions/2018-11-15_Color-charts/'

## ferme toutes les fenêtres d'affichage
plt.close('all')

## Lit l'image RAW stockée sous la forme d'un fichier TIFF 16 bits
mon_image = cv2.imread('/content/DSC_0166.NEF', cv2.IMREAD_ANYDEPTH)

## Affichage de la taille de l'image
print( mon_image.shape )

## Affiche l'image RAW en niveau de gris
plt.figure(1)
plt.imshow(mon_image)
plt.set_cmap('gray')
plt.title('Image RAW')
# Out:
# (120, 160)
# Text(0.5, 1.0, 'Image RAW')

# %%
# !pip install spectral
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 4.2 MB/s eta 0:00:00
# ...

# %%
hauteur, largeur, canaux = 60, 80, 3

# Créez une matrice de dimensions spécifiées
CR_img = np.zeros((hauteur, largeur, canaux), dtype=np.uint8)

# %%
CR_img[: ,: ,0] = mon_image[0:120:2, 0:160:2]
CR_img[: ,: ,1] = mon_image[0:120:2, 1:160:2]
CR_img[: ,: ,1] = mon_image[1:120:2, 1:160:2]

# %%
plt.figure(1)
plt.imshow(CR_img)
##plt.set_cmap('color')
plt.title('Image RAW')
# Out:
# Text(0.5, 1.0, 'Image RAW')
